# %% [markdown]
# <img src="unnamed.jpg" width="700">

# %% [markdown]
# # 2

# %% [markdown]
# <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/57e9787d3e7e96c76c9b0e247fecbf8d3b25335d" width="500">
#
# <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/a330427b13e76a6b588aea8c396774d61bf2a222" width="500">

# %%
data1 = rgamma(100, shape = 2, scale = 3)

# %%
# 2(a)
options(repr.plot.width=15, repr.plot.height=5)
plot.ecdf(data1, col="red")
# Out:
# Plot with title “ecdf(x)”

# %%
# 2(b)
X2 = seq(0,50,1)
data2 = sapply(X2, function(x) pgamma(q = x, shape = 2, scale = 3))

X3 = seq(0,0.99,0.01)
data3 = sapply(X3, function(x) qgamma(p = x, shape = 2, scale = 3))

# %%
plot.ecdf(data1, col="red")
lines(X2, data2, col="green")  
lines(data3, X3, col="blue")
legend(20,0.5, legend=c("rgamma", "pgamma", "qgamma"), col=c("red", "green","blue"), lty=1, cex=0.8)
# Out:
# Plot with title “ecdf(x)”

# %% [markdown]
# # 3 (c)

# %%
r <- function() runif(1,0,1) > 0.5

# %%
sim <- function(K){
    result = array(0, dim = 1000)
    for (i in c(1:1000)){
        for (k in c(1:K)){
            result[i] = result[i] + r() * 2 / (3^k)
        }
    }
    return(result)
}

# %%
plot.ecdf(sim(1))
# Out:
# Plot with title “ecdf(x)”

# %%
plot.ecdf(sim(2))
# Out:
# Plot with title “ecdf(x)”

# %%
plot.ecdf(sim(5))
# Out:
# Plot with title “ecdf(x)”

# %% [markdown]
# # 5(c)

# %%
r = function(p) {
    return(rbinom(1,1,p))
}

# %%
sim <- function(){
    r1=-1
    r2=-1
    p=0.9
    n=0
    while (r1==r2){
        r1 = r(p)
        r2 = r(p)
        n = n+1
    }
    return(n)
}

# %%
n_s= array(0, dim = 1000)
for(i in c(1:1000)){
    n_s[i] = sim()
}

# %%
mean(n_s)
# Out:
# [1] 5.374

# %% [markdown]
# Exact number:

# %%
1/0.18
# Out:
# [1] 5.555556
